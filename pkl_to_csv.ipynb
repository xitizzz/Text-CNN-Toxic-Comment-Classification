# %%
import pandas as pd
import

# %%
pd.read_csv('./Submission_LSTM.pkl')
# Out:
#                   id  identity_hate    insult   obscene  severe_toxic  \
# 0            6044863            NaN       NaN       NaN           NaN
# 1            6102620            NaN       NaN       NaN           NaN
# 2           14563293            NaN       NaN       NaN           NaN
# 3           21086297            NaN       NaN       NaN           NaN
# 4           22982444            NaN       NaN       NaN           NaN
# 5           24388733       0.000010  0.000038  0.000040      0.000009
# 6           26195914            NaN       NaN       NaN           NaN
# 7           31769073            NaN       NaN       NaN           NaN
# 8           35289443            NaN       NaN       NaN           NaN
# 9           38393350            NaN       NaN       NaN           NaN
# 10          51720630            NaN       NaN       NaN           NaN
# 11          52808210            NaN       NaN       NaN           NaN
# ...
